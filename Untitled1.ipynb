# %% [markdown]
# <a href="https://colab.research.google.com/github/AKVITA380/Deep-Learning-6-July-2024/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Multiclass classification with keras
#
# Number of classes is more then two then it is multiclass classification problem

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# Step 1 Read Data

# %%
import pandas as pd
url=("https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/main/mobile_train.csv")
df=pd.read_csv(url)
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %% [markdown]
# Step 2 Check Basic Quality of Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
df.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['price_range'].unique()
# Out:
# array([1, 2, 3, 0])

# %% [markdown]
# Price Range
#
# 1. 0 - Cheap
# 2. 1 - Moderate
# 3. 2 - High
# 4. 3 - Very Expensive
#
# Four Classes to Predict in above DataFrame

# %% [markdown]
# Step 3 Seperate X and Y (price_range)

# %%
X=df.drop(columns=['price_range'])
Y=df[['price_range']]

# %%
X.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi
# ...

# %%
Y.head()
# Out:
#    price_range
# 0            1
# 1            2
# 2            2
# 3            2
# 4            1

# %% [markdown]
# Step 4 Perform Preprocessing On X

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
num_pipe = Pipeline(steps=[('impute',SimpleImputer(strategy="median")),
                           ('scaler',StandardScaler())]).set_output(transform='pandas')

# %%
X_pre = num_pipe.fit_transform(X)
X_pre.head()
# Out:
#    battery_power      blue  clock_speed  dual_sim        fc    four_g  \
# 0      -0.902597 -0.990050     0.830779 -1.019184 -0.762495 -1.043966
# 1      -0.495139  1.010051    -1.253064  0.981177 -0.992890  0.957886
# 2      -1.537686  1.010051    -1.253064  0.981177 -0.532099  0.957886
# 3      -1.419319  1.010051     1.198517 -1.019184 -0.992890 -1.043966
# 4       1.325906  1.010051    -0.395011 -1.019184  2.002254  0.957886
#
#    int_memory     m_dep  mobile_wt   n_cores        pc  px_height  px_width  \
# 0   -1.380644  0.340740   1.349249 -1.101971 -1.305750  -1.408949 -1.146784
# 1    1.155024  0.687548  -0.120059 -0.664768 -0.645989   0.585778  1.704465
# 2    0.493546  1.381165   0.134244  0.209639 -0.645989   1.392684  1.074968
# 3   -1.215274  1.034357  -0.261339  0.646842 -0.151168   1.286750  1.236971
# 4    0.658915  0.340740   0.021220 -1.101971  0.673534   1.268718 -0.091452
#
#         ram      sc_h      sc_w  talk_time   three_g  touch_screen      wifi
# ...

# %% [markdown]
# This is applicable to multiclass classification only,get onehot encoding for target features

# %% [markdown]
# Step 5 Apply Train Test Split

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest, ytrain,ytest =train_test_split(X_pre,Y,test_size=0.2,random_state=42)
